# %% [markdown]
# # Relatório de Teste A/B

# %% [markdown]
# Nesse relatório, nosso grupo foi além devido a implementação de testes, que pode ser visualizado na sessão 6, denominada "Testes estatísticos".

# %% [markdown]
# ### Sumário

# %% [markdown]
# 1. **Introdução**
#    - Apresentação do objetivo do relatório e das estratégias propostas para otimizar a taxa de conversão e a qualidade dos leads do WizardOn.
#
# 2. **Objetivo do Teste**
#    - Avaliar se a alteração na localização do formulário na página aumenta a taxa de conversão de leads de 5% para 7%.
#
# 3. **Método**
#    - Descrição do design do teste A/B, incluindo a definição dos grupos de controle e experimental, as métricas utilizadas e as hipóteses testadas.
#
# 4. **Teste A/B**
#    - Detalhamento das alterações realizadas na página e da metodologia de implementação do teste.
#
# 5. **Preparação dos Dados**
#    - Descrição dos dados coletados, processos de carregamento e unificação dos dados, e cálculo da taxa de conversão.
#
# 6. **Descrição dos Dados**
#    - Estatísticas descritivas das sessões, conversões e taxa de conversão.
#
# 7. **Testes Estatísticos**
#    - Apresentação e interpretação dos resultados dos testes t e intervalos de confiança.
#
# 8. **Análise dos Resultados**
#    - Visualização gráfica dos resultados e interpretação detalhada dos dados obtidos.
#
# 9. **Limitações**
#    - Discussão das limitações do teste realizado, como período curto, amostra pequena e múltiplas mudanças simultâneas.
#
# 10. **Conclusão**
#     - Resumo dos achados e recomendações para futuras otimizações da página com base nos resultados obtidos.

# %% [markdown]
# ## 1. Introdução

# %% [markdown]
# O documento propõe uma solução focada na otimização da comunicação da modalidade de ensino WizardOn, na estabilização e aumento da taxa de conversão de visitas para leads e na melhoria da qualidade dos leads capturados para a Wizard by Pearson. Isso será alcançado através da análise dos problemas identificados e da implementação de novas estratégias.

# %% [markdown]
# ### 1.1. Objetivo do teste

# %% [markdown]
# O objetivo deste teste A/B é avaliar se a alteração na localização do formulário na página aumenta a taxa de conversão de leads de 5% para 7%, em comparação com a versão atual.

# %% [markdown]
# ## 2. Método

# %% [markdown]
# ### 2.1. Design do Teste

# %% [markdown]
# O teste será realizado com duas páginas: a página de controle será a própria página da Wizard com a campanha do Dia dos Namorados. A página do grupo experimental terá duas sessões: uma com a campanha do dia dos namorados e outra com uma alteração, que consiste em mover o formulário de interesse da primeira sessão para a segunda, ao lado da explicação sobre o curso.

# %% [markdown]
# ### 2.2. Métricas

# %% [markdown]
# #### 2.2.1 Métrica primária

# %% [markdown]
# A principal métrica para avaliar o sucesso do teste é a taxa de conversão dos leads. Os dados são extraídos manualmente do HubSpot pela equipe da Wizard e enviados ao orientador da turma, que repassa os novos resultados aos alunos diariamente.

# %% [markdown]
# #### 2.2.2 Métricas secundárias

# %% [markdown]
# A métrica secundária é a taxa de cliques no botão do WhatsApp e Participe. As matrículas dos alunos também podem ser realizadas por esse canal, mas não receberemos imediatamente o número de leads gerados por ele. Portanto, continuaremos monitorando a quantidade de cliques no botão.

# %% [markdown]
# ### 2.3 Hipóteses Estatísticas

# %% [markdown]
# #### Primeira Proposta
#
# ### Hipótese
# Usuários não percebem o efeito no botão "Participe".
#
# ### Justificativa da Hipótese
# Ao clicar no botão "Participe", o formulário é exibido imediatamente na primeira seção da página, o que pode causar confusão ou a impressão de que o botão não funciona, pois o formulário já está visível.
#
# ### Proposta B do Teste A/B
# Ao deslocar o formulário para a segunda sessão da página, os usuários irão perceber melhor o efeito do botão “Participe” e farão mais inscrições pelo formulário
#
# ### Validação da Hipótese
# A hipótese será validada se mover o formulário resultar em um aumento no número de cliques no botão "Participe" e nas inscrições através do formulário.
#
# ### Variáveis
#
# **Variável Independente:**
# A posição do formulário de inscrição (primeira seção vs. segunda seção da página).
#
# **Variável Dependente:**
# Número de cliques no botão "Participe" e número de inscrições no curso através do formulário.
#
# ### Grupos
#
# **Grupo Experimental:**
# Usuários que acessam a versão da página onde o formulário está na segunda seção.
#
# **Grupo de Controle:**
# Usuários que acessam a versão da página onde o formulário permanece na primeira seção.

# %% [markdown]
# #### Segunda Proposta
#
# ### Hipótese
# Usuários não se inscrevem no formulário pois não possuem informações suficientes sobre o curso.
#
# ### Justificativa da Hipótese
# Os usuários podem hesitar em preencher e enviar o formulário de inscrição porque sentem que não possuem informações detalhadas sobre o curso. Sem essas informações, eles podem se sentir inseguros ou não suficientemente motivados para completar a inscrição.
#
# ### Proposta B do Teste A/B
#
# Ao deslocarmos o conteúdo explicativo do curso para o lado do formulário, os usuários irão se inscrever mais.
#
# ### Validação da Hipótese
# A hipótese será validada se a adição do conteúdo explicativo do curso ao lado do formulário resultar em um aumento no número de envios de formulários.
#
# ### Variáveis
#
# **Variável Independente:**
# A presença de conteúdo explicativo do curso ao lado do formulário (sim ou não).
#
# **Variável Dependente:**
# Número de envios de formulários de inscrição.
#
# ### Grupos
#
# **Grupo Experimental:**
# Usuários que acessam a versão da página onde o conteúdo explicativo do curso está ao lado do formulário (6% dos usuários).
#
# **Grupo de Controle:**
# Usuários que acessam a versão da página onde o formulário está sem o conteúdo explicativo ao lado (94% dos usuários).

# %% [markdown]
# ### 2.4. Período do Teste

# %% [markdown]
# A página experimental estará no ar de 04 de junho de 2024 a 14 de junho de 2024. Os dados sobre a evolução do teste serão recebidos diariamente e poderão ser extraídos tanto pelo HubSpot quanto pelo Looker.

# %% [markdown]
# ## 3. Teste A/B

# %% [markdown]
# As mudanças foram realizadas na página de desenvolvimento da Wizard, acessível através de um link junto com o código-fonte, que podia ser acessado por meio de um tutorial. As principais alterações foram feitas em dois arquivos, "home" e "formulário", modificando o HTML e o CSS da página.
#
# Após as configurações e a reestruturação da Proposta B, a página foi implantada no ambiente de homologação da Wizard e, no dia 04 de junho, foi lançada ao ar.
#
# Para mais detalhes sobre o processo, acesse a seguinte documentação: [Código - Proposta B para Teste A/B.](https://github.com/Inteli-College/2024-1B-T04-SI10-G03/blob/main/document/sprint%203/%5BDocumenta%C3%A7%C3%A3o%20C%C3%B3digo%5D%20Proposta%20B%20para%20Teste%20A_B.pdf)

# %% [markdown]
# ## 4. Preparação dos dados

# %% [markdown]
# Os resultados do teste serão disponibilizados em duas plataformas: HubSpot e Looker.
#
# Até o momento, foram disponibilizados apenas dados relacionados a quantidade de sessões e a quantidade de leads. Acredita-se que, ao longo da próxima sprint, a Wizard fornecerá mais dados para complementar a análise.

# %% [markdown]
# ### 4.1. Descrição dos Dados

# %% [markdown]
# - **`grupo`**: A qual grupo aquela linha de dados se refere.
# - **`data_inicial`**: A data inicial que os dados foram coletados.
# - **`data_final`**: A data final que os dados foram coletados.
# - **`sessions`**: Número total de sessões no site.
# - **`numero_leads`**: Quantidade de submissões de formulários.

# %% [markdown]
# ### 4.2. Carregamento dos dados

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_looker = pd.read_csv('/content/drive/Shareddrives/M10_SI/dados-analise-quantitativa-m10/looker - 11_06.csv')

# %%
df_hubspot = pd.read_csv('/content/drive/Shareddrives/M10_SI/dados-analise-quantitativa-m10/Hubspot - 11_06.csv')

# %% [markdown]
# ### 4.3. Informações dos dados

# %%
df_looker.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Pagina        6 non-null      object
#  1   Sessoes       6 non-null      int64
#  2   Data inicial  6 non-null      object
#  3   Data final    6 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 320.0+ bytes

# %%
df_hubspot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Pagina        6 non-null      object
#  1   Conversoes    6 non-null      int64
#  2   Data inicial  6 non-null      object
#  3   Data final    6 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 320.0+ bytes

# %% [markdown]
# ### 4.4. Visualização dos dados

# %%
df_looker
# Out:
#               Pagina  Sessoes Data inicial  Data final
# 0           Controle     6491   04/06/2024  11/06/2024
# 1  Teste B - Grupo 1      460   04/06/2024  11/06/2024
# 2  Teste B - Grupo 2      303   04/06/2024  11/06/2024
# 3  Teste B - Grupo 3      443   04/06/2024  11/06/2024
# 4  Teste B - Grupo 4      309   04/06/2024  11/06/2024
# 5  Teste B - Grupo 5      278   04/06/2024  11/06/2024

# %%
df_hubspot
# Out:
#               Pagina  Conversoes Data inicial  Data final
# 0           Controle         541   04/06/2024  11/06/2024
# 1  Teste B - Grupo 1          28   04/06/2024  11/06/2024
# 2  Teste B - Grupo 2          19   04/06/2024  11/06/2024
# 3  Teste B - Grupo 3          26   04/06/2024  11/06/2024
# 4  Teste B - Grupo 4          19   04/06/2024  11/06/2024
# 5  Teste B - Grupo 5          15   04/06/2024  11/06/2024

# %% [markdown]
# ### 4.5. Unificando os dataframes

# %%
dados = pd.concat([df_looker, df_hubspot['Conversoes']], axis=1)
dados
# Out:
#               Pagina  Sessoes Data inicial  Data final  Conversoes
# 0           Controle     6491   04/06/2024  11/06/2024         541
# 1  Teste B - Grupo 1      460   04/06/2024  11/06/2024          28
# 2  Teste B - Grupo 2      303   04/06/2024  11/06/2024          19
# 3  Teste B - Grupo 3      443   04/06/2024  11/06/2024          26
# 4  Teste B - Grupo 4      309   04/06/2024  11/06/2024          19
# 5  Teste B - Grupo 5      278   04/06/2024  11/06/2024          15

# %% [markdown]
# ### 4.6. Calculando a taxa de conversão

# %%
dados['taxa_conversao'] = ((dados['Conversoes'] / dados['Sessoes']) * 100).round(2)
dados
# Out:
#               Pagina  Sessoes Data inicial  Data final  Conversoes  \
# 0           Controle     6491   04/06/2024  11/06/2024         541
# 1  Teste B - Grupo 1      460   04/06/2024  11/06/2024          28
# 2  Teste B - Grupo 2      303   04/06/2024  11/06/2024          19
# 3  Teste B - Grupo 3      443   04/06/2024  11/06/2024          26
# 4  Teste B - Grupo 4      309   04/06/2024  11/06/2024          19
# 5  Teste B - Grupo 5      278   04/06/2024  11/06/2024          15
#
#    taxa_conversao
# 0            8.33
# 1            6.09
# 2            6.27
# 3            5.87
# 4            6.15
# 5            5.40

# %% [markdown]
# ## 5. Descrição dos dados

# %%
# Estatísticas descritivas para sessões
media_sessoes = dados['Sessoes'].mean()
desvio_padrao_sessoes = dados['Sessoes'].std()
mediana_sessoes = dados['Sessoes'].median()
min_sessoes = dados['Sessoes'].min()
max_sessoes = dados['Sessoes'].max()

# Estatísticas descritivas para conversões
media_conversoes = dados['Conversoes'].mean()
desvio_padrao_conversoes = dados['Conversoes'].std()
mediana_conversoes = dados['Conversoes'].median()
min_conversoes = dados['Conversoes'].min()
max_conversoes = dados['Conversoes'].max()

# Estatísticas descritivas para taxa de conversão
media_taxa_conversao = dados['taxa_conversao'].mean()
desvio_padrao_taxa_conversao = dados['taxa_conversao'].std()
mediana_taxa_conversao = dados['taxa_conversao'].median()
min_taxa_conversao = dados['taxa_conversao'].min()
max_taxa_conversao = dados['taxa_conversao'].max()

# Imprimir as estatísticas descritivas
print("Estatísticas Descritivas para Sessões:")
print(f"Média: {media_sessoes}")
print(f"Desvio Padrão: {desvio_padrao_sessoes}")
print(f"Mediana: {mediana_sessoes}")
print(f"Min: {min_sessoes}")
print(f"Max: {max_sessoes}")

print("\nEstatísticas Descritivas para Conversões:")
print(f"Média: {media_conversoes}")
print(f"Desvio Padrão: {desvio_padrao_conversoes}")
print(f"Mediana: {mediana_conversoes}")
print(f"Min: {min_conversoes}")
print(f"Max: {max_conversoes}")

print("\nEstatísticas Descritivas para Taxa de Conversão:")
print(f"Média: {media_taxa_conversao}%")
print(f"Desvio Padrão: {desvio_padrao_taxa_conversao}%")
print(f"Mediana: {mediana_taxa_conversao}%")
print(f"Min: {min_taxa_conversao}%")
print(f"Max: {max_taxa_conversao}%")
# Out:
# Estatísticas Descritivas para Sessões:
# Média: 1380.6666666666667
# Desvio Padrão: 2504.7180014258424
# Mediana: 376.0
# Min: 278
# Max: 6491
#
# Estatísticas Descritivas para Conversões:
# Média: 108.0
# Desvio Padrão: 212.1810547622007
# Mediana: 22.5
# Min: 15
# Max: 541
#
# Estatísticas Descritivas para Taxa de Conversão:
# Média: 6.351666666666667%
# Desvio Padrão: 1.0165907075449128%
# Mediana: 6.12%
# Min: 5.4%
# Max: 8.33%

# %% [markdown]
# ## 6. Testes estatísticos

# %% [markdown]
# ### 6.1 Teste t

# %% [markdown]
# **Hipótese nula (𝐻0):** A alteração na página (proposta B) não teve um impacto significativo na taxa de conversão (as taxas de conversão dos grupos de controle e experimental são iguais).
#
# **Hipótese alternativa (𝐻𝐴):** A alteração na página (proposta B) teve um impacto significativo na taxa de conversão (as taxas de conversão dos grupos de controle e experimental são diferentes).

# %% [markdown]
# A escolha de utilizar o teste t para proporções em vez do teste t convencional se deve à natureza dos dados de conversão. Em testes A/B que avaliam taxas de conversão, estamos lidando com proporções, onde cada conversão é um evento binário (sucesso ou falha) e as taxas de conversão representam a proporção de sucessos em relação ao total de tentativas (sessões).
#
# O teste t convencional é mais adequado para comparar médias de dados contínuos, enquanto o teste t de proporções leva em conta a natureza binária das conversões e a variabilidade específica das proporções, proporcionando uma análise mais precisa e relevante para este tipo de dados.
#
# Portanto, o uso do teste t de proporções permite uma avaliação mais adequada da significância estatística das diferenças observadas nas taxas de conversão entre os grupos de controle e experimental.

# %%
import pandas as pd
import numpy as np
from scipy import stats

def teste_t_proporcao(df, grupo_controle, grupo_teste):
    controle = df[df['Pagina'] == grupo_controle]
    n1 = controle['Sessoes'].values[0]
    x1 = controle['Conversoes'].values[0]

    teste = df[df['Pagina'] == grupo_teste]
    n2 = teste['Sessoes'].values[0]
    x2 = teste['Conversoes'].values[0]

    p1 = x1 / n1
    p2 = x2 / n2

    p_combinada = (x1 + x2) / (n1 + n2)

    denominador = np.sqrt(p_combinada * (1 - p_combinada) * (1/n1 + 1/n2))

    t_stat = (p1 - p2) / denominador

    df = min(n1, n2) - 1

    p_valor = 2 * (1 - stats.t.cdf(np.abs(t_stat), df))

    return t_stat, p_valor

grupo_controle = 'Controle'
grupo_teste = 'Teste B - Grupo 3'

t_stat, p_valor = teste_t_proporcao(dados, grupo_controle, grupo_teste)
print(f"Estatística t: {t_stat:.4f}")
print(f"Valor p: {p_valor:.4f}")

alpha = 0.05
if p_valor < alpha:
    print('Rejeitamos a hipótese nula (as taxas de conversão dos grupos de controle e experimental são significativamente diferentes).')
else:
    print('Não rejeitamos a hipótese nula (não há diferença significativa nas taxas de conversão entre os grupos de controle e experimental).')
# Out:
# Estatística t: 1.8323
# Valor p: 0.0676
# Não rejeitamos a hipótese nula (não há diferença significativa nas taxas de conversão entre os grupos de controle e experimental).

# %% [markdown]
# ### 6.2 Intervalo de confiança

# %% [markdown]
# O intervalo de confiança é uma medida que estima a precisão das taxas de conversão observadas nos grupos de controle e experimental. Ele fornece uma faixa de valores que provavelmente contém a verdadeira taxa de conversão populacional, considerando a variação amostral. Para este relatório, utilizamos um intervalo de confiança de 95%.

# %%
import pandas as pd
import numpy as np
from scipy import stats

# Função para calcular intervalo de confiança para proporções
def calc_intervalo_confianca(p, n, alpha=0.05):
    z = stats.norm.ppf(1 - alpha/2)
    margin_of_error = z * np.sqrt((p * (1 - p)) / n)
    return (p - margin_of_error, p + margin_of_error)

# Recriar o DataFrame a partir da imagem fornecida
dados = pd.DataFrame({
    'Pagina': ['Controle', 'Teste B - Grupo 1', 'Teste B - Grupo 2', 'Teste B - Grupo 3', 'Teste B - Grupo 4', 'Teste B - Grupo 5'],
    'Sessoes': [6491, 460, 303, 443, 309, 278],
    'Data_inicial': ['04/06/2024']*6,
    'Data_final': ['11/06/2024']*6,
    'Conversoes': [541, 28, 19, 26, 19, 15],
    'taxa_conversao': [8.33, 6.09, 6.27, 5.87, 6.15, 5.40]
})

# Filtrar para os grupos de interesse
dados_interesse = dados[dados['Pagina'].isin(['Controle', 'Teste B - Grupo 3'])].copy()

# Calculando intervalo de confiança para o grupo controle e o grupo 3
intervalos_confianca = []
for index, row in dados_interesse.iterrows():
    p = row['taxa_conversao'] / 100
    n = row['Sessoes']
    intervalo = calc_intervalo_confianca(p, n)
    intervalos_confianca.append(intervalo)

# Adicionando a nova coluna usando .loc para evitar o warning
dados_interesse.loc[:, 'intervalo_confianca'] = intervalos_confianca

# Formatando intervalos com menos casas decimais
dados_interesse['intervalo_confianca'] = dados_interesse['intervalo_confianca'].apply(lambda x: (round(x[0]*100, 2), round(x[1]*100, 2)))

print(dados_interesse[['Pagina', 'taxa_conversao', 'intervalo_confianca']])
# Out:
#               Pagina  taxa_conversao intervalo_confianca
# 0           Controle            8.33         (7.66, 9.0)
# 3  Teste B - Grupo 3            5.87        (3.68, 8.06)

# %% [markdown]
# Os intervalos de confiança ajudam a entender a precisão das taxas de conversão estimadas e permitem comparar se as diferenças observadas entre os grupos de controle e experimental são estatisticamente significativas.
#
# Resultados:
#
# * **Grupo de Controle:** A taxa de conversão é de 8.33%, com um intervalo de confiança de [7.71%, 8.95%].
#
# * **Grupo Experimental 3:** A taxa de conversão é de 5.87%, com um intervalo de confiança de [4.14%, 7.60%].

# %% [markdown]
# ## 7. Resultados Obtidos

# %% [markdown]
# ### 7.1 Visualização dos resultados

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig = make_subplots(rows=3, cols=1, shared_xaxes=True,
                    vertical_spacing=0.1, subplot_titles=("Sessões por Página", "Conversões por Página", "Taxa de Conversão por Página"))

fig.add_trace(go.Scatter(x=dados['Pagina'], y=dados['Sessoes'], mode='lines+markers', name='Sessões'), row=1, col=1)

fig.add_trace(go.Scatter(x=dados['Pagina'], y=dados['Conversoes'], mode='lines+markers', name='Conversões'), row=2, col=1)

fig.add_trace(go.Scatter(x=dados['Pagina'], y=dados['taxa_conversao'], mode='lines+markers', name='Taxa de Conversão (%)'), row=3, col=1)

fig.update_layout(height=800, width=800, title_text="Resultados do Teste A/B")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cdcb387e-153d-4045-bfe0-aa60386736d7" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cdcb387e-153d-4045-bfe0-aa60386736d7")) {                    Plotly.newPlot(                        "cdcb387e-153d-4045-bfe0-aa60386736d7",                        [{"mode":"lines+markers","name":"Sess\u00f5es","x":["Controle","Teste B - Grupo 1","Teste B - Grupo 2","Teste B - Grupo 3","Teste B - Grupo 4","Teste B - Grupo 5"],"y":[6491,460,303,443,309,278],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"lines+markers","name":"Convers\u00f5es","x":["Controle","Teste B - Grupo 1","Teste B - Grupo 2","Teste B - Grupo 3","Teste B - Grupo 4","Teste B - Grupo 5"],"y":[541,28,19,26,19,15],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"mode":"lines+markers","name":"Taxa de Convers\u00e3o (%)","x":["Controle","Teste B - Grupo 1","Teste B - Grupo 2","Teste B - Grupo 3","Teste B - Grupo 4","Teste B - Grupo 5"],"y":[8.33,6.09,6.27,5.87,6.15,5.4],"type":"scatter","xaxis":"x3","yaxis":"y3"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl" ...

# %% [markdown]
# ### 7.2 Intepretação dos resultados

# %% [markdown]
# #### **Resultados do Teste t**
#
# * ***t-statistic:*** *1.8323*
# * ***p-value:*** *0.0676*
#
# **1. t-statistic:** Este valor indica a magnitude da diferença entre as proporções das taxas de conversão dos grupos de controle e experimental em unidades de erro padrão. Um valor de 1.83 sugere que há uma diferença moderada entre as proporções das taxas de conversão.
#
# **2. p-value:** Este valor indica a probabilidade de observar uma diferença tão grande (ou maior) entre as proporções das taxas de conversão dos grupos de controle e experimental se a hipótese nula fosse verdadeira (isto é, se não houvesse diferença real entre as proporções).
#
#
# Como o p-value (0.0676) é maior que o nível de significância (α = 0.05), não rejeitamos a hipótese nula. Isso significa que não há evidências estatísticas de que as taxas de conversão dos grupos de controle e experimental são diferentes. Em outras palavras, a alteração na página (proposta B do teste A/B) não resultou em uma diferença significativa na taxa de conversão em comparação com o controle. Portanto, qualquer diferença observada pode ser atribuída ao acaso.

# %% [markdown]
# #### **Intervalo de confiança**
#
# * **Grupo de controle**: A taxa de conversão é de 8.33%, com um intervalo de confiança de [7.66%, 9.00%].
#
# * **Grupo Experimental 3:** A taxa de conversão é de 5.87%, com um intervalo de confiança de [3.68%, 8.06%].
#
# Os intervalos de confiança mostram que, embora a taxa de conversão do grupo experimental 3 seja menor que a do grupo de controle, as faixas de confiança se sobrepõem consideravelmente. Isso indica que a variação observada nas taxas de conversão pode ser atribuída à variação amostral, e não há uma diferença estatisticamente significativa entre os grupos.

# %% [markdown]
# ## 8. Limitações

# %% [markdown]
# O teste A/B realizado para a otimização da página da Wizard apresentou diversas limitações que precisam ser cuidadosamente consideradas para uma avaliação precisa dos resultados. Primeiramente, o período de teste foi relativamente curto, durando apenas uma semana. Essa brevidade pode não ter sido suficiente para capturar uma amostra representativa e consistente do comportamento dos usuários. Em períodos tão curtos, flutuações sazonais ou eventos específicos podem influenciar os resultados, comprometendo a generalização dos achados.

# %% [markdown]
# Outra limitação significativa foi a pequena amostra de usuários exposta às alterações na página B. A proporção limitada de participantes no grupo experimental afetou a significância estatística dos resultados, dificultando a detecção de diferenças significativas entre os grupos de controle e experimental. Com uma amostra reduzida, é mais difícil obter resultados conclusivos sobre a eficácia das mudanças implementadas.

# %% [markdown]
# Além disso, foram implementadas diversas mudanças simultâneas na página B, incluindo o reposicionamento do formulário, a adição de ícones representativos e a ampliação da imagem promocional. Embora essas alterações visassem melhorar a usabilidade e a estética, a multiplicidade de mudanças dificultou a identificação de quais modificações específicas tiveram impacto nas taxas de conversão. Essa abordagem múltipla impede uma análise clara sobre qual mudança foi realmente eficaz.

# %% [markdown]
# Outro aspecto a ser considerado são as variações no contexto de uso, como diferentes dispositivos, horários de acesso e perfis de usuário. Estas variações podem influenciar significativamente a interação dos usuários com a página, e o teste realizado não levou em conta os dados obtidos a partir  dessas segmentações adicionais, tendo em vista que a Pearson não estruturou o Google Analytics para capturá-los nas páginas B's. Isso pode limitar a compreensão do comportamento dos usuários e das necessidades específicas de diferentes segmentos, além, é claro, do impacto da outra versão da página na usabilidade dos usuários.

# %% [markdown]
# Por fim, a análise qualitativa não foi realizada, visto que todo esse relatório foi feito focando, principalmente, em métricas quantitativas, sem uma investigação profunda do feedback qualitativo dos usuários. Comentários e percepções dos usuários podem oferecer insights valiosos sobre a experiência e possíveis pontos de melhoria que não são capturados pelas métricas quantitativas.

# %% [markdown]
# Portanto, as principais limitações do teste A/B realizado incluem o período de teste curto, a pequena amostra de usuários no grupo experimental, a coleta de dados manual, a implementação de múltiplas mudanças simultâneas, a falta de segmentação no contexto de uso e a análise qualitativa limitada. Essas limitações devem ser levadas em consideração ao interpretar os resultados e ao planejar futuras otimizações.

# %% [markdown]
# ## 9 Conclusão

# %% [markdown]
# ### 9.1 Resumo dos achados

# %% [markdown]
# O teste A/B realizado para avaliar as alterações na página da Wizard teve como objetivo principal aumentar a taxa de conversão de leads em 7% e melhorar a qualidade dos leads capturados. Foram implementadas diversas modificações na página, incluindo o reposicionamento do formulário de inscrição para a segunda seção, a adição de ícones representativos dos produtos oferecidos e a ampliação da imagem promocional.
#
# No entanto, os resultados obtidos indicaram que essas mudanças não tiveram o impacto esperado. A análise estatística revelou uma estatística t de 1.8323 e um valor p de 0.0676, o que significa que não podemos rejeitar a hipótese nula. Portanto, não há evidências estatísticas de que as taxas de conversão dos grupos de controle e experimental são significativamente diferentes. Especificamente, a taxa de conversão do grupo experimental 3 foi de 5.87%, enquanto a do grupo de controle foi de 8.33%. Esses dados reforçam a conclusão de que as modificações implementadas não resultaram em um aumento significativo na taxa de conversão.

# %% [markdown]
# ### 9.2 Recomendações

# %% [markdown]
# Diante dos resultados obtidos, é essencial adotar uma abordagem mais detalhada e criteriosa para futuras otimizações da página. Abaixo estão algumas recomendações específicas para a Pearson continuar implementando e aprimorando o teste A/B:
#
# 1. **Extensão do período de teste:**
#    O período de uma semana é insuficiente para capturar uma amostra representativa do comportamento dos usuários. Recomenda-se estender o período de teste para pelo menos quatro semanas. Isso permitirá captar variações sazonais e comportamentais mais amplas, oferecendo dados mais robustos e representativos.
#
# 2. **Aumento da amostra experimental:**
#    A pequena amostra de usuários no grupo experimental limitou a significância estatística dos resultados. Sugerimos aumentar a proporção de usuários expostos às alterações na página. Uma divisão de 50% para cada grupo (controle e experimental) pode proporcionar um equilíbrio melhor para detectar diferenças significativas. Alternativamente, garantir que pelo menos 20% dos visitantes sejam alocados ao grupo experimental pode ajudar a obter dados mais significativos.
#
# 3. **Automatização da coleta de dados:**
#    A coleta manual de dados pode introduzir erros e inconsistências. Implementar sistemas automatizados para coleta e análise de dados, como Google Analytics, Mixpanel ou HubSpot, pode reduzir o risco de erros e aumentar a precisão dos insights derivados dos dados.
#
# 4. **Abordagem iterativa de mudanças:**
#    Testar múltiplas mudanças simultaneamente dificultou a identificação do impacto individual de cada alteração. Recomenda-se adotar uma abordagem iterativa, testando uma mudança por vez. Isso permitirá isolar e identificar o efeito de cada alteração individualmente, começando com aquelas que teoricamente têm maior impacto na experiência do usuário e na taxa de conversão.
#
# 5. **Segmentação adicional dos testes:**
#    Considerar variações no contexto de uso, como diferentes dispositivos (desktop vs. mobile), horários de acesso (diurno vs. noturno) e perfis de usuário. Realizar segmentações adicionais permitirá uma compreensão mais aprofundada do comportamento de diferentes grupos de usuários e adaptar a página para otimizar a conversão para cada segmento específico.
#
# 6. **Integração de feedback qualitativo:**
#    Além das métricas quantitativas, é crucial coletar feedback qualitativo dos usuários. Utilizar ferramentas de feedback, como pesquisas de satisfação e testes de usabilidade, pode oferecer insights valiosos sobre a experiência do usuário que não são capturados pelas métricas quantitativas. Isso permitirá identificar áreas de melhoria e ajustar a página de acordo com as necessidades e preferências dos usuários.
#
# 7. **Monitoramento contínuo e iterativo:**
#    Após implementar as mudanças recomendadas, é importante continuar monitorando e ajustando a página com base nos dados coletados. Um processo contínuo de teste e otimização assegura que a página permaneça eficaz e alinhada com as expectativas dos usuários. Realizar testes de acompanhamento para verificar se as mudanças estão mantendo o impacto positivo ao longo do tempo.
#
# Implementando essas recomendações, a Pearson poderá continuar otimizando a landing page de forma mais eficaz, melhorando a experiência do usuário e potencialmente aumentando as taxas de conversão de maneira sustentável. Essas ações não apenas contribuirão para alcançar os objetivos estabelecidos, mas também fortalecerão a capacidade da Wizard de competir no mercado educacional online, garantindo que a oferta de cursos atenda e supere as expectativas dos alunos.

# %% [markdown]
# # Resultados finais obtidos

# %% [markdown]
# ## Preparação dos dados finais

# %% [markdown]
# Abaixo é possível visualizar os resultados finais obtidos a partir do período completo de teste descrito no tópico 2.4(Período do Teste).

# %% [markdown]
# ### 10.1 Carregamento dos dados finais

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_looker_final = pd.read_csv('/content/drive/Shareddrives/M10_SI/dados-analise-quantitativa-m10/looker - 17_06.csv')

# %%
df_hubspot_final = pd.read_csv('/content/drive/Shareddrives/M10_SI/dados-analise-quantitativa-m10/Hubspot - 17_06.csv')

# %% [markdown]
# ### 10.2. Informações dos dados

# %%
df_looker_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Pagina        6 non-null      object
#  1   Sessoes       6 non-null      int64
#  2   Data inicial  6 non-null      object
#  3   Data final    6 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 320.0+ bytes

# %%
df_hubspot_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Pagina        6 non-null      object
#  1   Conversoes    6 non-null      int64
#  2   Data inicial  6 non-null      object
#  3   Data final    6 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 320.0+ bytes

# %% [markdown]
# ### 10.3. Visualização dos dados

# %%
df_looker_final
# Out:
#               Pagina  Sessoes Data inicial  Data final
# 0           Controle    13476   04/06/2024  17/06/2024
# 1  Teste B - Grupo 1      888   04/06/2024  17/06/2024
# 2  Teste B - Grupo 2      600   04/06/2024  17/06/2024
# 3  Teste B - Grupo 3      867   04/06/2024  17/06/2024
# 4  Teste B - Grupo 4      611   04/06/2024  17/06/2024
# 5  Teste B - Grupo 5      534   04/06/2024  17/06/2024

# %%
df_hubspot_final
# Out:
#               Pagina  Conversoes Data inicial  Data final
# 0           Controle         470   04/06/2024  17/06/2024
# 1  Teste B - Grupo 1          45   04/06/2024  17/06/2024
# 2  Teste B - Grupo 2          30   04/06/2024  17/06/2024
# 3  Teste B - Grupo 3          32   04/06/2024  17/06/2024
# 4  Teste B - Grupo 4          31   04/06/2024  17/06/2024
# 5  Teste B - Grupo 5          17   04/06/2024  17/06/2024

# %% [markdown]
# ### 10.4. Unificando os dataframes

# %%
dados = pd.concat([df_looker_final , df_hubspot_final['Conversoes']], axis=1)
dados
# Out:
#               Pagina  Sessoes Data inicial  Data final  Conversoes
# 0           Controle    13476   04/06/2024  17/06/2024         470
# 1  Teste B - Grupo 1      888   04/06/2024  17/06/2024          45
# 2  Teste B - Grupo 2      600   04/06/2024  17/06/2024          30
# 3  Teste B - Grupo 3      867   04/06/2024  17/06/2024          32
# 4  Teste B - Grupo 4      611   04/06/2024  17/06/2024          31
# 5  Teste B - Grupo 5      534   04/06/2024  17/06/2024          17

# %% [markdown]
# ### 10.5. Calculando a taxa de conversão

# %%
dados['taxa_conversao'] = ((dados['Conversoes'] / dados['Sessoes']) * 100).round(2)
dados
# Out:
#               Pagina  Sessoes Data inicial  Data final  Conversoes  \
# 0           Controle    13476   04/06/2024  17/06/2024         470
# 1  Teste B - Grupo 1      888   04/06/2024  17/06/2024          45
# 2  Teste B - Grupo 2      600   04/06/2024  17/06/2024          30
# 3  Teste B - Grupo 3      867   04/06/2024  17/06/2024          32
# 4  Teste B - Grupo 4      611   04/06/2024  17/06/2024          31
# 5  Teste B - Grupo 5      534   04/06/2024  17/06/2024          17
#
#    taxa_conversao
# 0            3.49
# 1            5.07
# 2            5.00
# 3            3.69
# 4            5.07
# 5            3.18

# %% [markdown]
# ## Descrição dos dados finais

# %%
# Estatísticas descritivas para sessões
media_sessoes = dados['Sessoes'].mean()
desvio_padrao_sessoes = dados['Sessoes'].std()
mediana_sessoes = dados['Sessoes'].median()
min_sessoes = dados['Sessoes'].min()
max_sessoes = dados['Sessoes'].max()

# Estatísticas descritivas para conversões
media_conversoes = dados['Conversoes'].mean()
desvio_padrao_conversoes = dados['Conversoes'].std()
mediana_conversoes = dados['Conversoes'].median()
min_conversoes = dados['Conversoes'].min()
max_conversoes = dados['Conversoes'].max()

# Estatísticas descritivas para taxa de conversão
media_taxa_conversao = dados['taxa_conversao'].mean()
desvio_padrao_taxa_conversao = dados['taxa_conversao'].std()
mediana_taxa_conversao = dados['taxa_conversao'].median()
min_taxa_conversao = dados['taxa_conversao'].min()
max_taxa_conversao = dados['taxa_conversao'].max()

# Imprimir as estatísticas descritivas
print("Estatísticas Descritivas para Sessões:")
print(f"Média: {media_sessoes}")
print(f"Desvio Padrão: {desvio_padrao_sessoes}")
print(f"Mediana: {mediana_sessoes}")
print(f"Min: {min_sessoes}")
print(f"Max: {max_sessoes}")

print("\nEstatísticas Descritivas para Conversões:")
print(f"Média: {media_conversoes}")
print(f"Desvio Padrão: {desvio_padrao_conversoes}")
print(f"Mediana: {mediana_conversoes}")
print(f"Min: {min_conversoes}")
print(f"Max: {max_conversoes}")

print("\nEstatísticas Descritivas para Taxa de Conversão:")
print(f"Média: {media_taxa_conversao}%")
print(f"Desvio Padrão: {desvio_padrao_taxa_conversao}%")
print(f"Mediana: {mediana_taxa_conversao}%")
print(f"Min: {min_taxa_conversao}%")
print(f"Max: {max_taxa_conversao}%")
# Out:
# Estatísticas Descritivas para Sessões:
# Média: 2829.3333333333335
# Desvio Padrão: 5217.8639946501735
# Mediana: 739.0
# Min: 534
# Max: 13476
#
# Estatísticas Descritivas para Conversões:
# Média: 104.16666666666667
# Desvio Padrão: 179.44070515539852
# Mediana: 31.5
# Min: 17
# Max: 470
#
# Estatísticas Descritivas para Taxa de Conversão:
# Média: 4.25%
# Desvio Padrão: 0.8880765732750753%
# Mediana: 4.345%
# Min: 3.18%
# Max: 5.07%

# %% [markdown]
# ## 10.6 introdução sobre novos dados

# %% [markdown]
# ## Introdução
# A análise dos dados de desempenho de sessões e conversões em um site foi conduzida em duas fases distintas, utilizando as plataformas HubSpot e Looker. Inicialmente, foram disponibilizados dados relacionados à quantidade de sessões e leads, enquanto na segunda fase foram fornecidos dados mais completos e estruturados. Este texto apresenta uma comparação detalhada entre os dados iniciais e os dados finais, com foco nas mudanças observadas nas sessões, conversões e taxa de conversão ao longo do período analisado.

# %% [markdown]
# Os dados iniciais foram coletados e disponibilizados nas plataformas HubSpot e Looker, contendo informações sobre sessões e conversões. As estatísticas descritivas dos dados iniciais são as seguintes:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Sendo assim, na fase final da coleta de dados, foi disponibilizada uma nova tabela combinando informações mais detalhadas das plataformas HubSpot e Looker, incluindo a adição de novas categorias de grupo. As estatísticas descritivas dos dados finais são as seguintes:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ao comparar os dados iniciais com os dados finais, observamos algumas diferenças significativas:
#
# - **Sessões**: Houve um aumento substancial na média de sessões, passando de 1380.67 para 2829.33, com um aumento correspondente no desvio padrão, indicando maior variabilidade nos dados finais. O valor máximo também cresceu significativamente, de 6491 para 13476. <br><br>
#
# - **Conversões**: A média de conversões diminuiu ligeiramente, de 108.0 para 104.17, e a variabilidade das conversões também reduziu, conforme indicado pela diminuição no desvio padrão de 212.18 para 179.44. <br><br>
#
# - **Taxa de Conversão**: A taxa de conversão média diminuiu de 6.35% para 4.25%. Esta redução pode indicar que, apesar do aumento no número de sessões, a eficácia em converter essas sessões em leads diminuiu. A variabilidade na taxa de conversão também diminuiu, como mostra a redução no desvio padrão de 1.02% para 0.89%. <br><br>
#
# Portanto, os dados finais mostram um aumento no tráfego do site (sessões), mas com uma leve queda na eficiência de conversão. Esta análise destaca a importância de não apenas aumentar o número de visitantes, mas também de focar na qualidade das interações para melhorar a taxa de conversão. A continuação da coleta de dados e a análise detalhada dos novos insights fornecidos pela Wizard serão essenciais para estratégias de otimização contínua.

# %% [markdown]
# ## Testes estatísticos dos resultados finais

# %% [markdown]
# Com base nos métodos apresentados durante o tópico 6 foram refeitos o Teste t e intervalo de confiança referentes aos dados finais apresentados.

# %% [markdown]
# ### 11.1 Teste t

# %%
import pandas as pd
import numpy as np
from scipy import stats

def teste_t_proporcao(df, grupo_controle, grupo_teste):
    controle = df[df['Pagina'] == grupo_controle]
    n1 = controle['Sessoes'].values[0]
    x1 = controle['Conversoes'].values[0]

    teste = df[df['Pagina'] == grupo_teste]
    n2 = teste['Sessoes'].values[0]
    x2 = teste['Conversoes'].values[0]

    p1 = x1 / n1
    p2 = x2 / n2

    p_combinada = (x1 + x2) / (n1 + n2)

    denominador = np.sqrt(p_combinada * (1 - p_combinada) * (1/n1 + 1/n2))

    t_stat = (p1 - p2) / denominador

    df = min(n1, n2) - 1

    p_valor = 2 * (1 - stats.t.cdf(np.abs(t_stat), df))

    return t_stat, p_valor

grupo_controle = 'Controle'
grupo_teste = 'Teste B - Grupo 3'

t_stat, p_valor = teste_t_proporcao(dados, grupo_controle, grupo_teste)
print(f"Estatística t: {t_stat:.4f}")
print(f"Valor p: {p_valor:.4f}")

alpha = 0.05
if p_valor < alpha:
    print('Rejeitamos a hipótese nula (as taxas de conversão dos grupos de controle e experimental são significativamente diferentes).')
else:
    print('Não rejeitamos a hipótese nula (não há diferença significativa nas taxas de conversão entre os grupos de controle e experimental).')
# Out:
# Estatística t: -0.3156
# Valor p: 0.7524
# Não rejeitamos a hipótese nula (não há diferença significativa nas taxas de conversão entre os grupos de controle e experimental).

# %% [markdown]
# Analisar resultados (LARI)

# %% [markdown]
# **Resultados do Teste t de Proporção** <br>
# - **Estatística t**: -0.3156
# - **Valor p**: 0.7524
# Com um nível de significância (α) de 0.05, o p-valor de 0.7524 é muito maior que α. Isso indica que **não rejeitamos a hipótese nula**, ou seja, não há evidências suficientes para afirmar que existe uma diferença significativa nas taxas de conversão entre o grupo de controle e o grupo experimental (Teste B - Grupo 3).

# %% [markdown]
# A análise estatística dos dados finais revelou os seguintes pontos principais: <br><br>
#
# **Sem diferença significativa**:
#
# O Teste t de proporção mostrou que não há uma diferença estatisticamente significativa entre as taxas de conversão do grupo de controle e do grupo experimental Teste B - Grupo 3. O valor p alto (0.7524) indica que qualquer diferença observada é provavelmente devido ao acaso. <br><br>
#
# **Implicações para a estratégia**:
#
# Esses resultados sugerem que as mudanças implementadas no grupo experimental não tiveram um impacto significativo na taxa de conversão em comparação com o grupo de controle. Portanto, as estratégias e intervenções específicas testadas no Grupo 3 não demonstraram uma eficácia que seja superior à abordagem atual do controle. <br><br>
#
# **Recomendações**:
#
# - Reavaliar as mudanças específicas aplicadas no grupo experimental para identificar possíveis melhorias ou ajustes que possam aumentar a eficácia.
# - Continuar a coleta de dados e realizar análises adicionais com outros grupos experimentais para identificar estratégias potencialmente mais eficazes.
# - Considerar a aplicação de outras metodologias estatísticas ou de machine learning para explorar os dados de forma mais abrangente. <br><br>
#
#
# Logo, a análise dos resultados estatísticos fornece insights importantes para a tomada de decisão, ajudando a direcionar esforços futuros para estratégias que possam realmente impactar positivamente a taxa de conversão.

# %% [markdown]
# ### 11.2 Intervalo de confiança

# %%
import pandas as pd
import numpy as np
from scipy import stats

# Função para calcular intervalo de confiança para proporções
def calc_intervalo_confianca(p, n, alpha=0.05):
    z = stats.norm.ppf(1 - alpha/2)
    margin_of_error = z * np.sqrt((p * (1 - p)) / n)
    return (p - margin_of_error, p + margin_of_error)

# Recriar o DataFrame a partir da imagem fornecida
dados = pd.DataFrame({
    'Pagina': ['Controle', 'Teste B - Grupo 1', 'Teste B - Grupo 2', 'Teste B - Grupo 3', 'Teste B - Grupo 4', 'Teste B - Grupo 5'],
    'Sessoes': [13476, 888, 600, 867, 611, 534],
    'Data_inicial': ['04/06/2024']*6,
    'Data_final': ['17/06/2024']*6,
    'Conversoes': [470, 45, 30, 32, 31, 17],
    'taxa_conversao': [3.5, 5.1, 5.0, 3.7, 5.1, 3.2]
})

# Filtrar para os grupos de interesse
dados_interesse = dados[dados['Pagina'].isin(['Controle', 'Teste B - Grupo 3'])].copy()

# Calculando intervalo de confiança para o grupo controle e o grupo 3
intervalos_confianca = []
for index, row in dados_interesse.iterrows():
    p = row['taxa_conversao'] / 100
    n = row['Sessoes']
    intervalo = calc_intervalo_confianca(p, n)
    intervalos_confianca.append(intervalo)

# Adicionando a nova coluna usando .loc para evitar o warning
dados_interesse.loc[:, 'intervalo_confianca'] = intervalos_confianca

# Formatando intervalos com menos casas decimais
dados_interesse['intervalo_confianca'] = dados_interesse['intervalo_confianca'].apply(lambda x: (round(x[0]*100, 2), round(x[1]*100, 2)))

print(dados_interesse[['Pagina', 'taxa_conversao', 'intervalo_confianca']])
# Out:
#               Pagina  taxa_conversao intervalo_confianca
# 0           Controle             3.5        (3.19, 3.81)
# 3  Teste B - Grupo 3             3.7        (2.44, 4.96)

# %% [markdown]
# Os resultados dos intervalos de confiança para as taxas de conversão dos grupos de interesse são apresentados abaixo:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Os intervalos de confiança calculados fornecem insights valiosos sobre a precisão das taxas de conversão observadas:
#
# 1. **Grupo de Controle**:
#
# A taxa de conversão foi de 3.5%, com um intervalo de confiança de 3.19% a 3.81%. Este intervalo estreito indica uma estimativa precisa da taxa de conversão, refletindo a alta quantidade de sessões (13,476) no grupo de controle. <br><br>
#
# 2. **Teste B - Grupo 3**:
#
# A taxa de conversão foi de 3.7%, com um intervalo de confiança de 2.44% a 4.96%. Este intervalo mais amplo indica maior incerteza na estimativa da taxa de conversão, o que é esperado devido ao menor número de sessões (867) no grupo experimental. <br><br>
#
# **Precisão da Estimativa**:
#
# - A precisão da estimativa da taxa de conversão é maior no grupo de controle devido ao maior volume de dados.
# - A menor margem de erro proporciona uma confiança maior na taxa de conversão observada.
# - No grupo experimental (Teste B - Grupo 3), a maior variabilidade reflete a menor amostra, sugerindo a necessidade de uma amostragem maior para obter uma estimativa mais precisa. <br><br>
#
# **Sobreposição dos Intervalos**:
#
# A sobreposição dos intervalos de confiança entre os grupos de controle e experimental indica que a diferença nas taxas de conversão não é estatisticamente significativa.
# Ou seja, comprova os resultados do Teste t de proporção, reforçando a conclusão de que não há uma diferença significativa entre os grupos.
# Esses resultados indicam que, com base nos dados atuais, as intervenções aplicadas no grupo Teste B - Grupo 3 não resultaram em uma melhoria significativa na taxa de conversão em comparação com o grupo de controle. Recomenda-se continuar testando e ajustando estratégias, considerando também o aumento do tamanho da amostra para obter estimativas mais precisas e confiáveis.

# %% [markdown]
# ## Resultados finais obtidos

# %% [markdown]
# ### 12.1 Visualização dos resultados finais

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig = make_subplots(rows=3, cols=1, shared_xaxes=True,
                    vertical_spacing=0.1, subplot_titles=("Sessões por Página", "Conversões por Página", "Taxa de Conversão por Página"))

fig.add_trace(go.Scatter(x=dados['Pagina'], y=dados['Sessoes'], mode='lines+markers', name='Sessões'), row=1, col=1)

fig.add_trace(go.Scatter(x=dados['Pagina'], y=dados['Conversoes'], mode='lines+markers', name='Conversões'), row=2, col=1)

fig.add_trace(go.Scatter(x=dados['Pagina'], y=dados['taxa_conversao'], mode='lines+markers', name='Taxa de Conversão (%)'), row=3, col=1)

fig.update_layout(height=800, width=800, title_text="Resultados do Teste A/B")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e19dc57b-df89-4829-a5f9-5072392063ec" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e19dc57b-df89-4829-a5f9-5072392063ec")) {                    Plotly.newPlot(                        "e19dc57b-df89-4829-a5f9-5072392063ec",                        [{"mode":"lines+markers","name":"Sess\u00f5es","x":["Controle","Teste B - Grupo 1","Teste B - Grupo 2","Teste B - Grupo 3","Teste B - Grupo 4","Teste B - Grupo 5"],"y":[13476,888,600,867,611,534],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"lines+markers","name":"Convers\u00f5es","x":["Controle","Teste B - Grupo 1","Teste B - Grupo 2","Teste B - Grupo 3","Teste B - Grupo 4","Teste B - Grupo 5"],"y":[470,45,30,32,31,17],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"mode":"lines+markers","name":"Taxa de Convers\u00e3o (%)","x":["Controle","Teste B - Grupo 1","Teste B - Grupo 2","Teste B - Grupo 3","Teste B - Grupo 4","Teste B - Grupo 5"],"y":[3.5,5.1,5.0,3.7,5.1,3.2],"type":"scatter","xaxis":"x3","yaxis":"y3"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{" ...

# %%
import plotly.graph_objects as go

# Crie uma figura
fig = go.Figure()

fig.add_trace(go.Bar(
    x=df_looker_final['Pagina'],
    y=df_looker_final['Sessoes'],
    name='Sessões',
    marker_color='blue'
))
fig.update_layout(
    title="Distribuição de Sessões por Página",
    xaxis_title="Página",
    yaxis_title="Número de Sessões",
    xaxis_tickangle=-45,
    template="plotly_white",
    height=400,
    width=800
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fe84bfc8-f18b-4cc0-a168-d887d99e7f4f" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe84bfc8-f18b-4cc0-a168-d887d99e7f4f")) {                    Plotly.newPlot(                        "fe84bfc8-f18b-4cc0-a168-d887d99e7f4f",                        [{"marker":{"color":"blue"},"name":"Sess\u00f5es","x":["Controle","Teste B - Grupo 1","Teste B - Grupo 2","Teste B - Grupo 3","Teste B - Grupo 4","Teste B - Grupo 5"],"y":[13476,888,600,867,611,534],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatterc ...

# %% [markdown]
# 1. **Distribuição dos Dados**:
#
# O grupo "Controle" tem um número significativamente maior de sessões em comparação com todos os grupos de "Teste B".
# Todos os grupos de "Teste B" (Grupo 1 a Grupo 5) têm um número muito baixo de sessões, quase no mesmo nível, e bem abaixo do grupo "Controle". <br><br>
#
# 2. **Comportamento Geral**:
#
# O grupo "Controle" está claramente se destacando com um número de sessões superior a 10.000.
# Os grupos de "Teste B" estão todos abaixo de 2.000 sessões, indicando que nenhuma das variações testadas conseguiu atrair tantas sessões quanto o grupo "Controle". <br><br>
#
# 3. **Discrepâncias**:
#
# A diferença acentuada entre o grupo "Controle" e os grupos de "Teste B" sugere que as modificações ou variações introduzidas nos testes não foram eficazes em atrair mais sessões.
# É notável que todos os grupos de "Teste B" performaram de maneira semelhante, indicando que talvez os testes não foram variados o suficiente ou que todos os grupos falharam em abordar um fator crítico que está presente no grupo "Controle". <br><br>
#
# 4. **Interpretação dos Resultados**:
#
# O grupo "Controle" está recebendo significativamente mais tráfego, o que pode explicar porque também tem um número muito maior de conversões, conforme observado no gráfico anterior.
# Os resultados sugerem que as mudanças implementadas nos grupos de "Teste B" não tiveram o impacto desejado em atrair tráfego adicional ou que houve algum problema na implementação dos testes que não foi identificado inicialmente. <br><br>
#
# 5. **Recomendações**:
#
# Realizar uma análise detalhada do grupo "Controle" para identificar os fatores que estão contribuindo para o seu sucesso em atrair sessões. Esses fatores podem incluir estratégias de marketing, otimização de SEO, campanhas publicitárias, entre outros.
# Revisar as mudanças implementadas nos grupos de "Teste B" para verificar se houve alguma inconsistência ou se as variações foram significativas o suficiente para testar a hipótese de melhoria.
# Considerar novas variações ou estratégias de teste baseadas nas características bem-sucedidas identificadas no grupo "Controle".
# Focar em estratégias para aumentar o tráfego nos grupos de "Teste B", como campanhas de marketing direcionadas, melhorias em SEO, e análise de palavras-chave.
# O gráfico sugere uma necessidade urgente de reavaliar a abordagem utilizada nos testes de "Teste B", pois nenhuma das variações foi capaz de atrair mais sessões do que o grupo "Controle". Com o tráfego significativamente menor, os grupos de "Teste B" naturalmente terão menos conversões, reforçando a importância de entender e replicar o sucesso do grupo "Controle".

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Bar(
    x=df_hubspot_final['Pagina'],
    y=df_hubspot_final['Conversoes'],
    name='Conversões',
    marker_color='orange'
))

fig.update_layout(
    title="Conversões por Página",
    xaxis_title="Página",
    yaxis_title="Número de Conversões",
    xaxis_tickangle=-45,
    template="plotly_white",
    height=400,
    width=800
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2550e23b-2f2c-4286-a26e-ce3577d6e41c" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2550e23b-2f2c-4286-a26e-ce3577d6e41c")) {                    Plotly.newPlot(                        "2550e23b-2f2c-4286-a26e-ce3577d6e41c",                        [{"marker":{"color":"orange"},"name":"Convers\u00f5es","x":["Controle","Teste B - Grupo 1","Teste B - Grupo 2","Teste B - Grupo 3","Teste B - Grupo 4","Teste B - Grupo 5"],"y":[470,45,30,32,31,17],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercar ...

# %% [markdown]
# 1. **Distribuição dos Dados**:
#
# O grupo "Controle" tem um número significativamente maior de conversões em comparação com todos os grupos de "Teste B".
# Todos os grupos de "Teste B" (Grupo 1 a Grupo 5) têm um número muito baixo de conversões, quase no mesmo nível, e bem abaixo do grupo "Controle". <br><br>
#
# 2. **Comportamento Geral**:
#
# O grupo "Controle" está claramente se destacando com um número de conversões superior a 400.
# Os grupos de "Teste B" estão todos abaixo de 100 conversões, indicando que nenhuma das variações testadas conseguiu superar ou sequer igualar o desempenho do grupo "Controle". <br><br>
#
# 3. **Discrepâncias**:
#
# A diferença acentuada entre o grupo "Controle" e os grupos de "Teste B" sugere que as modificações ou variações introduzidas nos testes não foram eficazes em melhorar as conversões.
# É notável que todos os grupos de "Teste B" performaram de maneira semelhante, indicando que talvez os testes não foram variados o suficiente ou que todos os grupos falharam em abordar um fator crítico que está presente no grupo "Controle". <br><br>
#
# 4. **Interpretação dos Resultados**:
#
# O grupo "Controle" servindo como base de comparação está claramente mais eficaz em termos de conversões.
# Os resultados sugerem que as mudanças implementadas nos grupos de "Teste B" não tiveram o impacto desejado ou que houve algum problema na implementação dos testes que não foi identificado inicialmente. <br><br>
#
# 5. **Recomendações**:
#
# Realizar uma análise detalhada do grupo "Controle" para identificar os fatores que estão contribuindo para o seu sucesso. Esses fatores podem incluir design da página, conteúdo, chamadas para ação, usabilidade, entre outros.
# Revisar as mudanças implementadas nos grupos de "Teste B" para verificar se houve alguma inconsistência ou se as variações foram significativas o suficiente para testar a hipótese de melhoria.
# Considerar novas variações ou estratégias de teste baseadas nas características bem-sucedidas identificadas no grupo "Controle".
# Testar elementos individuais (como layout, texto, cores, CTAs) separadamente para entender melhor quais componentes têm maior impacto nas conversões.
# O gráfico sugere uma necessidade urgente de reavaliar a abordagem utilizada nos testes de "Teste B", pois nenhuma das variações foi capaz de superar ou mesmo aproximar o desempenho do grupo "Controle".

# %%
import plotly.express as px
fig = px.scatter(
    dados,
    x='Sessoes',
    y='Conversoes',
    size='Conversoes',
    opacity=0.8,
    title='Conversões vs Sessões'
)
fig.update_layout(
    template="plotly_white",
    xaxis=dict(title='Sessões'),
    yaxis=dict(title='Conversões'),
    height=400,
    width=600,
    margin=dict(l=20, r=20, t=30, b=20),
    showlegend=False
)

fig.update_xaxes(showline=True, linewidth=1, linecolor='black', mirror=True)
fig.update_yaxes(showline=True, linewidth=1, linecolor='black', mirror=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2130ddb7-fa18-4811-9d56-d209b4a88c0a" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2130ddb7-fa18-4811-9d56-d209b4a88c0a")) {                    Plotly.newPlot(                        "2130ddb7-fa18-4811-9d56-d209b4a88c0a",                        [{"hovertemplate":"Sessoes=%{x}\u003cbr\u003eConversoes=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","opacity":0.8,"size":[470,45,30,32,31,17],"sizemode":"area","sizeref":1.175,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[13476,888,600,867,611,534],"xaxis":"x","y":[470,45,30,32,31,17],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line": ...

# %% [markdown]
# 1. **Distribuição dos Dados**:
#
# - A maior parte dos pontos de dados está concentrada no canto inferior esquerdo do gráfico, indicando que a maioria das páginas tem tanto um número baixo de sessões quanto de conversões.
# Existe um ponto fora da curva localizado na extremidade direita do gráfico, representando uma página com um número muito maior de sessões e conversões em comparação com as outras, que no caso é a página de controle. <br><br>
#
# 2. **Comportamento Geral**:
#
# - A tendência geral mostra que, com o aumento do número de sessões, o número de conversões também tende a aumentar. No entanto, a maioria das páginas não alcança altos valores de sessões ou conversões.
# O ponto isolado sugere uma página que teve um desempenho excepcionalmente bom, tanto em atrair sessões quanto em gerar conversões. <br><br>
#
# 3. **Discrepâncias**:
#
# - A diferença acentuada entre a maioria dos pontos e o ponto isolado sugere que a performance das páginas é muito variável. Pode ser interessante investigar o que faz com que essa página específica se destaque em termos de sessões e conversões. <br><br>
#
# 4. **Interpretação dos Resultados**:
#
# - Páginas com poucas sessões e poucas conversões podem indicar que essas páginas não são tão atraentes ou não estão sendo promovidas de maneira eficaz.
# A página com alta performance poderia servir como um modelo para entender quais fatores contribuem para um aumento significativo nas sessões e conversões. Fatores a serem investigados incluem o conteúdo da página, a estratégia de marketing associada a ela, e a usabilidade da página. <br><br>
#
# 5. **Recomendações**:
#
# Realizar uma análise mais detalhada da página com alta performance para identificar práticas recomendadas que possam ser aplicadas a outras páginas.
# Considerar estratégias para aumentar as sessões nas páginas com baixas conversões, como campanhas de marketing direcionadas ou melhorias no SEO.
# Avaliar a experiência do usuário e o conteúdo das páginas com baixa performance para identificar áreas de melhoria.
# O gráfico oferece uma visão clara de que há um desempenho desigual entre as páginas, sugerindo a necessidade de uma análise mais aprofundada para replicar o sucesso da página de alta performance em outras páginas.

# %% [markdown]
# ### 12.2 Intepretação dos resultados

# %% [markdown]
# #### **Resultados do Teste t**
#
# * ***t-statistic:*** *-0.3156*
# * ***p-value:*** *0.7524*
#
# **1. t-statistic:** Este valor indica a magnitude da diferença entre as proporções das taxas de conversão dos grupos de controle e experimental em unidades de erro padrão. Um valor de -0.3156 sugere que não há uma diferença significativa entre as proporções das taxas de conversão, indicando que não há diferença clara entre os grupos B e o controle.
#
# **2. p-value:** Este valor indica a probabilidade de observar uma diferença tão grande (ou maior) entre as proporções das taxas de conversão dos grupos de controle e experimental se a hipótese nula fosse verdadeira (isto é, se não houvesse diferença real entre as proporções).
#
#
# Como o p-value (0.7524) é maior que o nível de significância (α = 0.05), não rejeitamos a hipótese nula. Isso significa que não há evidências estatísticas suficientes de que as taxas de conversão dos grupos de controle e experimental se diferem. Em outras palavras, a alteração na página (proposta B do teste A/B) pode não ter resultado em uma diferença significativa na taxa de conversão em comparação com o controle. Portanto, pode ser que as diferenças observadas se devam ao acaso.

# %% [markdown]
# #### **Intervalo de confiança**
#
# * **Grupo de controle**: A taxa de conversão é de 3.5%, com um intervalo de confiança de [3.19%, 3.81%].
#
# * **Grupo Experimental 3:** A taxa de conversão é de 3.7%, com um intervalo de confiança de [2.44%, 4.96%].
#
# Os intervalos de confiança mostram que, embora a taxa de conversão do grupo experimental 3 seja maior que a do grupo de controle, as faixas de confiança se sobrepõem consideravelmente. Essa sobreposição sugere que a variação observada nas taxas de conversão pode estar relacionada à variação amostral. Portanto, a diferença de +0.2% entre o grupo experimental e o grupo de controle pode não ser estatisticamente significativa, indicando que não há evidência suficiente para concluir que a diferença observada não seja devido ao acaso.

# %% [markdown]
# #### **Conclusão da interpretação:**
#
# Os resultados dos testes estatísticos - incluindo o teste t, demonstram que as alterações implementadas na página do grupo experimental (proposta B) não resultaram em uma diferença significativa na taxa de conversão em comparação com o grupo de controle.
#
# Apesar das diversas modificações visuais e de navegação, como o reposicionamento do formulário, a adição de ícones e a ampliação da area destinada imagem promocional, não podemos concluir que as mudanças ocasionaram em um impacto significativo na taxa de conversão do site.
#
# Portanto, mesmo com um aumento de 0.2% na taxa de conversão, pode ser que essa diferença tenha sido ocasionada devido ao acaso. Mas mesmo com esse cenário ainda é possível aproveitar e mudanças, que podem posteriormente serem individualmente inseridas em uma um teste A/B, ainda podendo ser utilizadas em estratégias futuras para atingir o resultado desejado referente a taxa de conversão.

# %% [markdown]
# ## Validação das hipotestes
#
# Com base nas hipoteses apresentadas:
#
# "Usuários não percebem o efeito no botão "Participe"."
#
# "Usuários não se inscrevem no formulário pois não possuem informações suficientes sobre o curso."
#
# Cujo os detalhes pode ser consultados no tópico 2.3 do documento.
#
# E no resultados apresentados no topico anterior(12.2), não e possivel validar as hipoteses alternativas criadas pelo grupo. Podendo ser futuramente em caso da extensão do periodo de testes ou testes que englobem cada modificação separadamente.
#
# Mas com os resultados obtidos até o atual momento, as hipoteses nulas serão mantidas:
#
# "não há relação entre o botão "Participe" e a taxa de conversão"
#
# "não há relação entre a posição das informações do curso e a taxa de conversão"

# %% [markdown]
# ## Conclusão

# %% [markdown]
# Os testes A/B realizados proporcionaram uma análise dos dados sobre o impacto das alterações implementadas na página de destino em relação à taxa de conversão. A partir dos dados coletados e das análises estatísticas realizadas, foram identificados insights que orientam tanto as conclusões quanto as recomendações estratégicas para otimizações futuras.
#
# Ao examinar a distribuição dos dados, ficou claro que o grupo experimental (Teste B - Grupo 3), que recebeu 30% dos leads, apresentou uma taxa de conversão ligeiramente superior em comparação ao grupo de controle, que recebeu 70% dos leads. Enquanto o grupo de controle alcançou uma taxa de conversão de 3.5%, com um intervalo de confiança de [3.19%, 3.81%], o grupo experimental alcançou 3.7%, com um intervalo de confiança de [2.44%, 4.96%]. Embora as faixas de confiança se sobrepõem consideravelmente, a taxa de conversão mais alta do grupo experimental indica um desempenho superior nesse aspecto específico.
#
# A análise estatística revelou um t-statistic de -0.3156 e um p-value de 0.7524, indicando que não há diferença estatisticamente significativa entre as taxas de conversão do grupo de controle e do grupo experimental. Isso sugere que qualquer variação observada nas taxas de conversão pode ser atribuída à aleatoriedade amostral e não a uma diferença real entre os grupos.
#
# Esses resultados indicam que, apesar da taxa de conversão ligeiramente melhor no grupo experimental, as alterações implementadas não resultaram em um aumento estatisticamente significativo na taxa de conversão em comparação com o grupo de controle. Para otimizações futuras, recomenda-se uma revisão detalhada das estratégias de teste A/B, considerando variações mais significativas e focando em elementos específicos que possam impactar diretamente a decisão do usuário. Essa abordagem ajudará a direcionar esforços para melhorar as taxas de conversão de maneira mais eficaz e sustentável.
